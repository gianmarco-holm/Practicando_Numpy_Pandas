# %% [markdown]
# # Ejercicios Nivel Avanzado

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Análisis Exploratorio de Datos:
#
# Utiliza funciones de Pandas para realizar un análisis exploratorio de un conjunto de datos. Esto podría incluir la generación de gráficos, estadísticas descriptivas, etc.

# %%
df = pd.read_csv('./dataset.csv')
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# 2. Pivoteo de Datos:
#
# Realiza la operación de pivoteo en tu DataFrame para transformar los datos de una manera diferente y analiza los resultados.

# %%
pivot = df.pivot_table(index='Author', columns='Year', values='User Rating', aggfunc='mean')
pivot
# Out:
# Year                        2009  2010  2011  2012  2013  2014  2015  2016  \
# Author
# Abraham Verghese             NaN   4.6   4.6   NaN   NaN   NaN   NaN   NaN
# Adam Gasiewski               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Adam Mansbach                NaN   NaN   4.8   NaN   NaN   NaN   NaN   NaN
# Adir Levy                    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Admiral William H. McRaven   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                          ...   ...   ...   ...   ...   ...   ...   ...
# Walter Isaacson              NaN   NaN   4.6   4.6   NaN   NaN   NaN   NaN
# William Davis                NaN   NaN   NaN   4.4   4.4   NaN   NaN   NaN
# William P. Young             4.6   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Wizards RPG Team             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zhi Gang Sha                 4.6   NaN   NaN   NaN   4.6   NaN   NaN   NaN
#
# Year                        2017  2018  2019
# Author
# ...
